# %% [markdown]
# variable - container that stores information
# identifier - name given to variable. functions,objects
# value - what comes after the identifier

# %% [markdown]
# DataTypes

# %%
pi_value = 3.14
type(pi_value)
# Out:
# float

# %%
balance = -10000000
type(balance)
# Out:
# int

# %%
is_loggedin = True
type(is_loggedin)
# Out:
# bool

# %%
comp_num = 3+2j
type(comp_num)
# Out:
# complex

# %%
job_level = 4.5
type(job_level)
# Out:
# float

# %%
name01 = input("Enter your username please : ")

# %%
age01 = int(input("Enter your age pleas : "))

# %%
type(age01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 type(age01)
#
# NameError: name 'age01' is not defined

# %% [markdown]
# 50 - age01

# %% [markdown]
# Type conversion- covertig data types

# %%
age_09 = 28

# %%
ex_age_og = str(age_09)

# %% [markdown]
# Mathematical Operators

# %%
### Addition (+)
### floor division

# %%
### floor division
8//3
# Out:
# 2

# %%
### modulus
8%3
# Out:
# 2

# %%
## raise to the power
8**3
# Out:
# 512

# %%
user_gross_pay = int(input("Enter your gross salary:"))

# %%
user_gross_pay = 300000
tax_rate = 0.36
net_gross_pay = (1-tax_rate) * user_gross_pay
print(f"tax_paid is {tax_rate} and net pay is: {net_gross_pay}")
# Out:
# tax_paid is 0.36 and net pay is: 192000.0
